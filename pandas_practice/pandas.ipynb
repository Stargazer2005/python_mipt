# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 2.1 MB/s eta 0:00:06
#     --------------------------------------- 0.2/11.5 MB 1.5 MB/s eta 0:00:08
#     --------------------------------------- 0.3/11.5 MB 1.6 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/11.5 MB 2.7 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/11.5 MB 3.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/11.5 MB 3.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.5 MB 3.7 MB/s eta 0:00:03
# ...

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # pd.Series
#
# Тип данных pd.Series представляет собой одномерный набор данных. Отсутствующий данные записываются как np.nan. Они не участвуют в вычислении средних, среднеквадратичных отклонений и т.д.
# Создание
#
# Создадим Series из списка температур

# %%
temperature = [0, 0, 1, np.nan, -1, -3, -5, -3, -6, np.nan, -8,- 9, -11, -14]
ser_1 = pd.Series(temperature)
ser_1
# Out:
# 0      0.0
# 1      0.0
# 2      1.0
# 3      NaN
# 4     -1.0
# 5     -3.0
# 6     -5.0
# 7     -3.0
# 8     -6.0
# 9      NaN
# 10    -8.0
# 11    -9.0
# 12   -11.0
# 13   -14.0
# dtype: float64

# %%
data = ['2021-01-' + str(i).zfill(2) for i in range(1, len(temperature) + 1)]
ser_2 = pd.Series(temperature, data)
ser_2
# Out:
# 2021-01-01     0.0
# 2021-01-02     0.0
# 2021-01-03     1.0
# 2021-01-04     NaN
# 2021-01-05    -1.0
# 2021-01-06    -3.0
# 2021-01-07    -5.0
# 2021-01-08    -3.0
# 2021-01-09    -6.0
# 2021-01-10     NaN
# 2021-01-11    -8.0
# 2021-01-12    -9.0
# 2021-01-13   -11.0
# 2021-01-14   -14.0
# dtype: float64

# %%
ser_2.isnull()
# Out:
# 2021-01-01    False
# 2021-01-02    False
# 2021-01-03    False
# 2021-01-04     True
# 2021-01-05    False
# 2021-01-06    False
# 2021-01-07    False
# 2021-01-08    False
# 2021-01-09    False
# 2021-01-10     True
# 2021-01-11    False
# 2021-01-12    False
# 2021-01-13    False
# 2021-01-14    False
# dtype: bool

# %%
ser_2.dropna(how="any")
# Out:
# 2021-01-01     0.0
# 2021-01-02     0.0
# 2021-01-03     1.0
# 2021-01-05    -1.0
# 2021-01-06    -3.0
# 2021-01-07    -5.0
# 2021-01-08    -3.0
# 2021-01-09    -6.0
# 2021-01-11    -8.0
# 2021-01-12    -9.0
# 2021-01-13   -11.0
# 2021-01-14   -14.0
# dtype: float64

# %%
ser_2.fillna(value=-7)
# Out:
# 2021-01-01     0.0
# 2021-01-02     0.0
# 2021-01-03     1.0
# 2021-01-04    -7.0
# 2021-01-05    -1.0
# 2021-01-06    -3.0
# 2021-01-07    -5.0
# 2021-01-08    -3.0
# 2021-01-09    -6.0
# 2021-01-10    -7.0
# 2021-01-11    -8.0
# 2021-01-12    -9.0
# 2021-01-13   -11.0
# 2021-01-14   -14.0
# dtype: float64

# %%
ser_3 = pd.Series(temperature, data, name='Temperature')
ser_3
# Out:
# 2021-01-01     0.0
# 2021-01-02     0.0
# 2021-01-03     1.0
# 2021-01-04     NaN
# 2021-01-05    -1.0
# 2021-01-06    -3.0
# 2021-01-07    -5.0
# 2021-01-08    -3.0
# 2021-01-09    -6.0
# 2021-01-10     NaN
# 2021-01-11    -8.0
# 2021-01-12    -9.0
# 2021-01-13   -11.0
# 2021-01-14   -14.0
# Name: Temperature, dtype: float64

# %% [markdown]
# ## Индексирование

# %%
print(ser_3[0])

print('-----------')

print(ser_3[1:3])

print('-----------')

print(ser_3[::-1])
# Out:
# 0.0
# -----------
# 2021-01-02    0.0
# 2021-01-03    1.0
# Name: Temperature, dtype: float64
# -----------
# 2021-01-14   -14.0
# 2021-01-13   -11.0
# 2021-01-12    -9.0
# 2021-01-11    -8.0
# 2021-01-10     NaN
# 2021-01-09    -6.0
# 2021-01-08    -3.0
# 2021-01-07    -5.0
# 2021-01-06    -3.0
# 2021-01-05    -1.0
# 2021-01-04     NaN
# 2021-01-03     1.0
# 2021-01-02     0.0
# 2021-01-01     0.0
# Name: Temperature, dtype: float64
# C:\Users\ilyar\AppData\Local\Temp\ipykernel_13772\2409160489.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(ser_3[0])

# %% [markdown]
# ## Индексирование по условию

# %%
date_range = pd.date_range('20190101', periods=10)
ser_4 = pd.Series(np.random.rand(10), date_range)
ser_4
# Out:
# 2019-01-01    0.768037
# 2019-01-02    0.964481
# 2019-01-03    0.452450
# 2019-01-04    0.220063
# 2019-01-05    0.311061
# 2019-01-06    0.881469
# 2019-01-07    0.647939
# 2019-01-08    0.592895
# 2019-01-09    0.211457
# 2019-01-10    0.416620
# Freq: D, dtype: float64

# %%
ser_4 > 0.45
# Out:
# 2019-01-01     True
# 2019-01-02     True
# 2019-01-03     True
# 2019-01-04    False
# 2019-01-05    False
# 2019-01-06     True
# 2019-01-07     True
# 2019-01-08     True
# 2019-01-09    False
# 2019-01-10    False
# Freq: D, dtype: bool

# %%
ser_4[ser_4 > 0.45]
# Out:
# 2019-01-01    0.768037
# 2019-01-02    0.964481
# 2019-01-03    0.452450
# 2019-01-06    0.881469
# 2019-01-07    0.647939
# 2019-01-08    0.592895
# dtype: float64

# %%
ser_4[(ser_4 > 0.7) | (ser_4 < 0.45)]
# Out:
# 2019-01-01    0.768037
# 2019-01-02    0.964481
# 2019-01-04    0.220063
# 2019-01-05    0.311061
# 2019-01-06    0.881469
# 2019-01-09    0.211457
# 2019-01-10    0.416620
# dtype: float64

# %% [markdown]
# ## Сортировка

# %%
ser_4.sort_index()
# Out:
# 2019-01-01    0.768037
# 2019-01-02    0.964481
# 2019-01-03    0.452450
# 2019-01-04    0.220063
# 2019-01-05    0.311061
# 2019-01-06    0.881469
# 2019-01-07    0.647939
# 2019-01-08    0.592895
# 2019-01-09    0.211457
# 2019-01-10    0.416620
# Freq: D, dtype: float64

# %%
ser_4.sort_values()
# Out:
# 2019-01-09    0.211457
# 2019-01-04    0.220063
# 2019-01-05    0.311061
# 2019-01-10    0.416620
# 2019-01-03    0.452450
# 2019-01-08    0.592895
# 2019-01-07    0.647939
# 2019-01-01    0.768037
# 2019-01-06    0.881469
# 2019-01-02    0.964481
# dtype: float64

# %% [markdown]
# ## Математические операции

# %%
ser_4 + 100
# Out:
# 2019-01-01    100.768037
# 2019-01-02    100.964481
# 2019-01-03    100.452450
# 2019-01-04    100.220063
# 2019-01-05    100.311061
# 2019-01-06    100.881469
# 2019-01-07    100.647939
# 2019-01-08    100.592895
# 2019-01-09    100.211457
# 2019-01-10    100.416620
# Freq: D, dtype: float64

# %%
np.exp(ser_4)
# Out:
# 2019-01-01    2.155530
# 2019-01-02    2.623427
# 2019-01-03    1.572159
# 2019-01-04    1.246156
# 2019-01-05    1.364873
# 2019-01-06    2.414445
# 2019-01-07    1.911598
# 2019-01-08    1.809219
# 2019-01-09    1.235476
# 2019-01-10    1.516826
# Freq: D, dtype: float64

# %%
np.mean(ser_4)
# Out:
# 0.5466473799218958

# %%
np.unique(ser_4)
# Out:
# array([0.2114566 , 0.22006345, 0.31106143, 0.41662023, 0.45245009,
#        0.59289517, 0.64793944, 0.76803662, 0.88146943, 0.96448136])

# %%
term_1 = pd.Series(np.random.randint(0, 10, 5))
term_2 = pd.Series(np.random.randint(0, 10, 6))

term_1 + term_2
# Out:
# 0     1.0
# 1    18.0
# 2    18.0
# 3    11.0
# 4    11.0
# 5     NaN
# dtype: float64

# %%
term_1.shape
# Out:
# (5,)

# %% [markdown]
# # DataFrame
#
# Объект DataFrame лучше всего представлять себе в виде обычной таблицы и это правильно, ведь DataFrame является табличной структурой данных. В любой таблице всегда присутствуют строки и столбцы. Столбцами в объекте DataFrame выступают объекты Series, строки которых являются их непосредственными элементами.

# %%
df1 = pd.DataFrame({
     'country': ['Kazakhstan', 'Russia', 'Belarus', 'China'],
     'population': [17.04, 143.5, 9.5, 1412],
     'square': [2724902, 17125191, 207600, 9597000]})
df1
# Out:
#       country  population    square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3       China     1412.00   9597000

# %%
data = [['Kazakhstan', 17.04, 2724902], ['Russia', 143.5, 17125191], ['Belarus', 9.5, 207600], ['China', 1412, 9597000]]
df2 = pd.DataFrame(data, columns=['country', 'population', 'square'])
df2
# Out:
#       country  population    square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3       China     1412.00   9597000

# %%
df2.columns
# Out:
# Index(['country', 'population', 'square'], dtype='object')

# %%
df2.values
# Out:
# array([['Kazakhstan', 17.04, 2724902],
#        ['Russia', 143.5, 17125191],
#        ['Belarus', 9.5, 207600],
#        ['China', 1412.0, 9597000]], dtype=object)

# %%
df2.columns = ['Страна', 'Население', 'Плошадь']
df2
# Out:
#        Страна  Население   Плошадь
# 0  Kazakhstan      17.04   2724902
# 1      Russia     143.50  17125191
# 2     Belarus       9.50    207600
# 3       China    1412.00   9597000

# %%
df1.index = ['KZ', 'RU', 'BY', 'CH']
df1
# Out:
#        country  population    square
# KZ  Kazakhstan       17.04   2724902
# RU      Russia      143.50  17125191
# BY     Belarus        9.50    207600
# CH       China     1412.00   9597000

# %%
df1.index.name = 'Country Code'
df1
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# CH                 China     1412.00   9597000

# %% [markdown]
# ## Индексирование

# %% [markdown]
# ### По колонкам

# %%
df1['country']
# Out:
# Country Code
# KZ    Kazakhstan
# RU        Russia
# BY       Belarus
# CH         China
# Name: country, dtype: object

# %%
df1.country
# Out:
# Country Code
# KZ    Kazakhstan
# RU        Russia
# BY       Belarus
# CH         China
# Name: country, dtype: object

# %%
df1[['country', 'square']]
# Out:
#                  country    square
# Country Code
# KZ            Kazakhstan   2724902
# RU                Russia  17125191
# BY               Belarus    207600
# CH                 China   9597000

# %% [markdown]
# ### По строкам

# %%
df1[1:2]
# Out:
#              country  population    square
# Country Code
# RU            Russia       143.5  17125191

# %%
df1[1:3]
# Out:
#               country  population    square
# Country Code
# RU             Russia       143.5  17125191
# BY            Belarus         9.5    207600

# %%
df1[:1:-1]
# Out:
#               country  population   square
# Country Code
# CH              China      1412.0  9597000
# BY            Belarus         9.5   207600

# %% [markdown]
# ### Индиксация по строкам при помощи .loc и .iloc
#
# .loc и .iloc --- это два взаимозаменяемых атрибута, которые позволяют индексировать по обеим осям сразу. Путаницы не возникает из-за фиксированного порядка перечисления осей.
#
#
#
# 1.  .loc - используется для доступа по строковой метке
# 2.  .iloc - используется для доступа по числовому значению (начиная от 0)

# %%
df1.loc['KZ']
# Out:
# country       Kazakhstan
# population         17.04
# square           2724902
# Name: KZ, dtype: object

# %%
df1.iloc[0]
# Out:
# country       Kazakhstan
# population         17.04
# square           2724902
# Name: KZ, dtype: object

# %%
df1.loc[['KZ', 'RU'], 'population']
# Out:
# Country Code
# KZ     17.04
# RU    143.50
# Name: population, dtype: float64

# %%
df1.loc['KZ' : 'BY' ,:]
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600

# %%
df1[df1.population > 10][['country', 'square']]
# Out:
#                  country    square
# Country Code
# KZ            Kazakhstan   2724902
# RU                Russia  17125191
# CH                 China   9597000

# %% [markdown]
# ## Редактирование таблиц

# %%
df1['density'] = df1['population'] / df1['square'] * 1e6
df1
# Out:
#                  country  population    square     density
# Country Code
# KZ            Kazakhstan       17.04   2724902    6.253436
# RU                Russia      143.50  17125191    8.379469
# BY               Belarus        9.50    207600   45.761079
# CH                 China     1412.00   9597000  147.129311

# %%
df1.drop(['density'], axis='columns')
# Out:
#                  country  population    square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# CH                 China     1412.00   9597000

# %% [markdown]
# # Работа с таблицами

# %%
dates = pd.date_range("20130101", periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -2.374512  0.168692 -0.329197  0.870498
# 2013-01-02  0.787941  0.084944 -0.187260  0.479138
# 2013-01-03  0.749407 -0.478877 -0.729164 -0.169358
# 2013-01-04  0.525883 -0.684798  2.178318  0.084630
# 2013-01-05  0.371872 -0.441320 -0.125749  0.912943
# 2013-01-06  0.204024  0.670126 -0.813114 -0.263688

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2013-01-01 -2.374512  0.168692 -0.329197  0.870498
# 2013-01-02 -1.586571  0.253636 -0.516457  1.349636
# 2013-01-03 -0.837164 -0.225241 -1.245621  1.180277
# 2013-01-04 -0.311281 -0.910039  0.932696  1.264908
# 2013-01-05  0.060591 -1.351359  0.806948  2.177850
# 2013-01-06  0.264615 -0.681233 -0.006166  1.914162

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.162453
# B    1.354924
# C    2.991431
# D    1.176631
# dtype: float64

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})

df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
df.groupby("Animal", group_keys=True)[['Max Speed']].apply(lambda x: x + 5)
# Out:
#           Max Speed
# Animal
# Falcon 0      385.0
#        1      375.0
# Parrot 2       29.0
#        3       31.0

# %%
df.groupby("Animal", group_keys=False)[['Max Speed']].apply(lambda x: x + 5)
# Out:
#    Max Speed
# 0      385.0
# 1      375.0
# 2       29.0
# 3       31.0

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Слияние таблиц

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.541228 -0.379580 -0.754448 -0.654013
# 1  0.205061 -0.341768 -0.869057 -0.348125
# 2  3.098538  0.381722 -1.606458 -1.666771
# 3 -0.097514  1.562006  0.132181 -1.949711
# 4 -1.376371  0.653854  0.893200  0.353526
# 5  1.485514  0.079451 -1.431610 -0.509390
# 6 -0.345412  1.706765  0.125945 -0.052215
# 7 -1.998315 -0.074694 -0.333507  1.366196
# 8  0.843504 -0.043645  0.953680 -0.252606
# 9 -0.161879  2.011397 -0.137933  0.179103

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.541228 -0.379580 -0.754448 -0.654013
#  1  0.205061 -0.341768 -0.869057 -0.348125
#  2  3.098538  0.381722 -1.606458 -1.666771,
#            0         1         2         3
#  3 -0.097514  1.562006  0.132181 -1.949711
#  4 -1.376371  0.653854  0.893200  0.353526
#  5  1.485514  0.079451 -1.431610 -0.509390
#  6 -0.345412  1.706765  0.125945 -0.052215,
#            0         1         2         3
#  7 -1.998315 -0.074694 -0.333507  1.366196
#  8  0.843504 -0.043645  0.953680 -0.252606
#  9 -0.161879  2.011397 -0.137933  0.179103]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.541228 -0.379580 -0.754448 -0.654013
# 1  0.205061 -0.341768 -0.869057 -0.348125
# 2  3.098538  0.381722 -1.606458 -1.666771
# 3 -0.097514  1.562006  0.132181 -1.949711
# 4 -1.376371  0.653854  0.893200  0.353526
# 5  1.485514  0.079451 -1.431610 -0.509390
# 6 -0.345412  1.706765  0.125945 -0.052215
# 7 -1.998315 -0.074694 -0.333507  1.366196
# 8  0.843504 -0.043645  0.953680 -0.252606
# 9 -0.161879  2.011397 -0.137933  0.179103

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'], 'value': [1, 2, 3, 5]})
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'], 'value': [5, 6, 7, 8]})
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=('_left', '_right'))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  bar           2  bar            6
# 3  baz           3  baz            7
# 4  foo           5  foo            5
# 5  foo           5  foo            8

# %% [markdown]
# # Чтение и запись данных
#
# Pandas поддерживает все самые популярные форматы хранения данных: csv, excel, sql, буфер обмена, html и многое другое

# %%
df1.to_csv('country.csv')

# %%
data = pd.read_csv('titanic_data.csv', sep=',')
data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
data = pd.read_csv('titanic_data.csv', sep=',', index_col='PassengerId')
data.head(10)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 1                 3                            Braund, Mr. Owen Harris
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 3                             Heikkinen, Miss. Laina
# 4                 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 3                           Allen, Mr. William Henry
# 6                 3                                   Moran, Mr. James
# 7                 1                            McCarthy, Mr. Timothy J
# 8                 3                     Palsson, Master. Gosta Leonard
# 9                 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                2                Nasser, Mrs. Nicholas (Adele Achem)
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# ...

# %%
data.tail(5)
# Out:
#              Pclass                                      Name     Sex   Age  \
# PassengerId
# 887               2                     Montvila, Rev. Juozas    male  27.0
# 888               1              Graham, Miss. Margaret Edith  female  19.0
# 889               3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890               1                     Behr, Mr. Karl Howell    male  26.0
# 891               3                       Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887              0      0      211536  13.00   NaN        S
# 888              0      0      112053  30.00   B42        S
# 889              1      2  W./C. 6607  23.45   NaN        S
# 890              0      0      111369  30.00  C148        C
# 891              0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Разная информация о датасете
#
# Можно узнать размер таблицы, информацию о значениях таблицы, различные статистики по значениям.

# %%
data.shape
# Out:
# (891, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 76.6+ KB

# %%
data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200
